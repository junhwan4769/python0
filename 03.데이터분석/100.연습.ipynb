# %%
import pandas as pd 
df = pd.read_csv('data/score.csv', index_col='지원번호')
df
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  북산고  197   90   85  100  95  85      Python
# 2번    정대만  북산고  184   40   35   50  55  25        Java
# 3번    송태섭  북산고  168   80   75   70  80  75  Javascript
# 4번    서태웅  북산고  187   40   60   70  75  80         NaN
# 5번    강백호  북산고  188   15   20   10  35  10         NaN
# 6번    변덕규  능남고  202   80  100   95  85  80           C
# 7번    황태산  능남고  188   55   65   45  40  35      PYTHON
# 8번    윤대협  능남고  190  100   85   90  95  95          C#

# %%
df.sort_values(['키'], ascending=[True])
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 3번    송태섭  북산고  168   80   75   70  80  75  Javascript
# 2번    정대만  북산고  184   40   35   50  55  25        Java
# 4번    서태웅  북산고  187   40   60   70  75  80         NaN
# 5번    강백호  북산고  188   15   20   10  35  10         NaN
# 7번    황태산  능남고  188   55   65   45  40  35      PYTHON
# 8번    윤대협  능남고  190  100   85   90  95  95          C#
# 1번    채치수  북산고  197   90   85  100  95  85      Python
# 6번    변덕규  능남고  202   80  100   95  85  80           C

# %%
df
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  북산고  197   90   85  100  95  85      Python
# 2번    정대만  북산고  184   40   35   50  55  25        Java
# 3번    송태섭  북산고  168   80   75   70  80  75  Javascript
# 4번    서태웅  북산고  187   40   60   70  75  80         NaN
# 5번    강백호  북산고  188   15   20   10  35  10         NaN
# 6번    변덕규  능남고  202   80  100   95  85  80           C
# 7번    황태산  능남고  188   55   65   45  40  35      PYTHON
# 8번    윤대협  능남고  190  100   85   90  95  95          C#

# %%
cols=df.columns
cols
# Out:
# Index(['이름', '학교', '키', '국어', '영어', '수학', '과학', '사회', 'SW특기'], dtype='object')

# %%
df[cols[2]]
# Out:
# 지원번호
# 1번    197
# 2번    184
# 3번    168
# 4번    187
# 5번    188
# 6번    202
# 7번    188
# 8번    190
# Name: 키, dtype: int64

# %%
df[cols[0:2]]
# Out:
#        이름   학교
# 지원번호
# 1번    채치수  북산고
# 2번    정대만  북산고
# 3번    송태섭  북산고
# 4번    서태웅  북산고
# 5번    강백호  북산고
# 6번    변덕규  능남고
# 7번    황태산  능남고
# 8번    윤대협  능남고

# %%
df[:'5번']
# Out:
#        이름   학교    키  국어  영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  북산고  197  90  85  100  95  85      Python
# 2번    정대만  북산고  184  40  35   50  55  25        Java
# 3번    송태섭  북산고  168  80  75   70  80  75  Javascript
# 4번    서태웅  북산고  187  40  60   70  75  80         NaN
# 5번    강백호  북산고  188  15  20   10  35  10         NaN

# %%
df[cols[:3]][:'3번']
# Out:
#        이름   학교    키
# 지원번호
# 1번    채치수  북산고  197
# 2번    정대만  북산고  184
# 3번    송태섭  북산고  168

# %%
df[['이름', 'SW특기']][:'8번']
# Out:
#        이름        SW특기
# 지원번호
# 1번    채치수      Python
# 2번    정대만        Java
# 3번    송태섭  Javascript
# 4번    서태웅         NaN
# 5번    강백호         NaN
# 6번    변덕규           C
# 7번    황태산      PYTHON
# 8번    윤대협          C#

# %%
df.loc['1번':'5번']
# Out:
#        이름   학교    키  국어  영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  북산고  197  90  85  100  95  85      Python
# 2번    정대만  북산고  184  40  35   50  55  25        Java
# 3번    송태섭  북산고  168  80  75   70  80  75  Javascript
# 4번    서태웅  북산고  187  40  60   70  75  80         NaN
# 5번    강백호  북산고  188  15  20   10  35  10         NaN

# %%
df.loc[['1번','5번'], ['이름','SW특기']]
# Out:
#        이름    SW특기
# 지원번호
# 1번    채치수  Python
# 5번    강백호     NaN

# %%
df.loc['1번':'5번', '이름':'SW특기']
# Out:
#        이름   학교    키  국어  영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  북산고  197  90  85  100  95  85      Python
# 2번    정대만  북산고  184  40  35   50  55  25        Java
# 3번    송태섭  북산고  168  80  75   70  80  75  Javascript
# 4번    서태웅  북산고  187  40  60   70  75  80         NaN
# 5번    강백호  북산고  188  15  20   10  35  10         NaN

# %%
df.loc['5번', '수학']
# Out:
# np.int64(10)

# %%
df.iloc[0:8, 0:4]
# Out:
#        이름   학교    키   국어
# 지원번호
# 1번    채치수  북산고  197   90
# 2번    정대만  북산고  184   40
# 3번    송태섭  북산고  168   80
# 4번    서태웅  북산고  187   40
# 5번    강백호  북산고  188   15
# 6번    변덕규  능남고  202   80
# 7번    황태산  능남고  188   55
# 8번    윤대협  능남고  190  100

# %%
df.iloc[0,8]
# Out:
# 'Python'

# %%
df.iloc[-1]
# Out:
# 이름      윤대협
# 학교      능남고
# 키       190
# 국어      100
# 영어       85
# 수학       90
# 과학       95
# 사회       95
# SW특기     C#
# Name: 8번, dtype: object

# %%
df.iloc[-1, -1]
# Out:
# 'C#'

# %%
df
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  북산고  197   90   85  100  95  85      Python
# 2번    정대만  북산고  184   40   35   50  55  25        Java
# 3번    송태섭  북산고  168   80   75   70  80  75  Javascript
# 4번    서태웅  북산고  187   40   60   70  75  80         NaN
# 5번    강백호  북산고  188   15   20   10  35  10         NaN
# 6번    변덕규  능남고  202   80  100   95  85  80           C
# 7번    황태산  능남고  188   55   65   45  40  35      PYTHON
# 8번    윤대협  능남고  190  100   85   90  95  95          C#

# %%
filt = df['키']>=190
filt
# Out:
# 지원번호
# 1번     True
# 2번    False
# 3번    False
# 4번    False
# 5번    False
# 6번     True
# 7번    False
# 8번     True
# Name: 키, dtype: bool

# %%
df[df['키']>=185]
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회    SW특기
# 지원번호
# 1번    채치수  북산고  197   90   85  100  95  85  Python
# 4번    서태웅  북산고  187   40   60   70  75  80     NaN
# 5번    강백호  북산고  188   15   20   10  35  10     NaN
# 6번    변덕규  능남고  202   80  100   95  85  80       C
# 7번    황태산  능남고  188   55   65   45  40  35  PYTHON
# 8번    윤대협  능남고  190  100   85   90  95  95      C#

# %%
df[~filt][['이름', '키']]
# Out:
#        이름    키
# 지원번호
# 2번    정대만  184
# 3번    송태섭  168
# 4번    서태웅  187
# 5번    강백호  188
# 7번    황태산  188

# %%
filt2 = (df['키'] < 170) | (df['키'] > 200)
df[filt2]
# Out:
#        이름   학교    키  국어   영어  수학  과학  사회        SW특기
# 지원번호
# 3번    송태섭  북산고  168  80   75  70  80  75  Javascript
# 6번    변덕규  능남고  202  80  100  95  85  80           C

# %%
filt = df['이름'].str.startswith('강')
df[filt]
# Out:
#        이름   학교    키  국어  영어  수학  과학  사회 SW특기
# 지원번호
# 5번    강백호  북산고  188  15  20  10  35  10  NaN

# %%
filt = df['이름'].str.contains('태')
df[filt]
# Out:
#        이름   학교    키  국어  영어  수학  과학  사회        SW특기
# 지원번호
# 3번    송태섭  북산고  168  80  75  70  80  75  Javascript
# 4번    서태웅  북산고  187  40  60  70  75  80         NaN
# 7번    황태산  능남고  188  55  65  45  40  35      PYTHON
