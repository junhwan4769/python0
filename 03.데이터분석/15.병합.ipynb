# %%
import pandas as pd

# %%
df_info = pd.read_csv('data/학생정보.csv')
df_info
# Out:
#   지원번호   이름   학교  학년    키        SW특기
# 0   1번  채치수  북산고   3  197      Python
# 1   2번  정대만  북산고   3  184        Java
# 2   3번  송태섭  북산고   3  168  Javascript
# 3   4번  서태웅  북산고   1  187         NaN
# 4   5번  강백호  북산고   1  188         NaN
# 5   6번  변덕규  능남고   3  202           C
# 6   7번  황태산  능남고   2  188      Python
# 7   8번  윤대협  능남고   2  190          C#

# %%
df_score = pd.read_csv('data/학생성적.csv')
df_score
# Out:
#   지원번호   국어   영어   수학  과학  사회
# 0   1번   90   85  100  95  85
# 1   2번   40   35   50  55  25
# 2   3번   80   75   70  80  75
# 3   4번   40   60   70  75  80
# 4   5번   15   20   10  35  10
# 5   6번   80  100   95  85  80
# 6   7번   55   65   45  40  35
# 7   8번  100   85   90  95  95

# %%
df = df_info.merge(df_score, how='left', left_on='지원번호', right_on='지원번호1')
df.drop(columns='지원번호1', inplace=True)
df.fillna({'SW특기':''}, inplace=True)
df.fillna(0, inplace=True)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df = df_info.merge(df_score, how='left', left_on='지원번호', right_on='지원번호1')
#       2 df.drop(columns='지원번호1', inplace=True)
#       3 df.fillna({'SW특기':''}, inplace=True)
#
# File c:\Users\AIPM2\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:10839, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10820 @Substitution("")
#   10821 @Appender(_merge_doc, indents=2)
#   10822 def merge(
#    (...)
#   10835     validate: MergeValidate | None = None,
#   10836 ) -> DataFrame:
#   10837     from pandas.core.reshape.merge import merge
# > 10839     return merge(
#   10840         self,
#   10841         right,
#   10842         how=how,
#   10843         on=on,
#   10844         left_on=left_on,
#   10845         right_on=right_on,
#   10846         left_index=left_index,
#   10847         right_index=right_index,
#   10848         sort=sort,
#   10849         suffixes=suffixes,
#   10850         copy=copy,
#   10851         indicator=indicator,
#   10852         validate=validate,
#   10853     )
#
# File c:\Users\AIPM2\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\reshape\merge.py:170, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     155     return _cross_merge(
#     156         left_df,
#     157         right_df,
#    (...)
#     167         copy=copy,
#     168     )
#     169 else:
# --> 170     op = _MergeOperation(
#     171         left_df,
#     172         right_df,
#     173         how=how,
#     174         on=on,
#     175         left_on=left_on,
#     176         right_on=right_on,
#     177         left_index=left_index,
#     178         right_index=right_index,
#     179         sort=sort,
#     180         suffixes=suffixes,
#     181         indicator=indicator,
#     182         validate=validate,
#     183     )
#     184     return op.get_result(copy=copy)
#
# File c:\Users\AIPM2\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\reshape\merge.py:794, in _MergeOperation.__init__(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
#     784     raise MergeError(msg)
#     786 self.left_on, self.right_on = self._validate_left_right_on(left_on, right_on)
#     788 (
#     789     self.left_join_keys,
#     790     self.right_join_keys,
#     791     self.join_names,
#     792     left_drop,
#     793     right_drop,
# --> 794 ) = self._get_merge_keys()
#     796 if left_drop:
#     797     self.left = self.left._drop_labels_or_levels(left_drop)
#
# File c:\Users\AIPM2\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\reshape\merge.py:1298, in _MergeOperation._get_merge_keys(self)
#    1296 rk = cast(Hashable, rk)
#    1297 if rk is not None:
# -> 1298     right_keys.append(right._get_label_or_level_values(rk))
#    1299 else:
#    1300     # work-around for merge_asof(right_index=True)
#    1301     right_keys.append(right.index._values)
#
# File c:\Users\AIPM2\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:1911, in NDFrame._get_label_or_level_values(self, key, axis)
#    1909     values = self.axes[axis].get_level_values(key)._values
#    1910 else:
# -> 1911     raise KeyError(key)
#    1913 # Check for duplicates
#    1914 if values.ndim > 1:
#
# KeyError: '지원번호1'

# %%
score = pd.read_csv('data/학생성적.csv')
score.to_csv('data/학생성적.csv', index=False)
score
# Out:
#   지원번호   국어   영어   수학  과학  사회
# 0   1번   90   85  100  95  85
# 1   2번   40   35   50  55  25
# 2   3번   80   75   70  80  75
# 3   4번   40   60   70  75  80
# 4   5번   15   20   10  35  10
# 5   6번   80  100   95  85  80
# 6   7번   55   65   45  40  35
# 7   8번  100   85   90  95  95

# %%
no = len(score)
no
# Out:
# 8

# %%
no = len(score)+1
no
# Out:
# 9

# %%
no = str(len(score)+1) + '번'
no
# Out:
# '9번'

# %%
idx = len(score)
no = f'{idx+1}번'
no
# Out:
# '9번'

# %%
score.loc[len(score)]=[no, 0, 0, 0, 0, 0]
score
# Out:
#   지원번호   국어   영어   수학  과학  사회
# 0   1번   90   85  100  95  85
# 1   2번   40   35   50  55  25
# 2   3번   80   75   70  80  75
# 3   4번   40   60   70  75  80
# 4   5번   15   20   10  35  10
# 5   6번   80  100   95  85  80
# 6   7번   55   65   45  40  35
# 7   8번  100   85   90  95  95
# 8   9번    0    0    0   0   0

# %%
filt = score['지원번호']=='9번'
idx = score[filt].index
if len(idx)==0: 
    print('없습니다')
else:
    score.drop(index=idx , inplace = True)
score
# Out:
# 없습니다
#   지원번호   국어   영어   수학  과학  사회
# 0   1번   90   85  100  95  85
# 1   2번   40   35   50  55  25
# 2   3번   80   75   70  80  75
# 3   4번   40   60   70  75  80
# 4   5번   15   20   10  35  10
# 5   6번   80  100   95  85  80
# 6   7번   55   65   45  40  35
# 7   8번  100   85   90  95  95

# %%
filt = score['지원번호']=='8번'
idx = score[filt].index
if len(idx)==0: 
    print('없습니다')
else:
    score[filt]
    score.drop(index=idx , inplace = True)
    print('삭제 완료')
score
# Out:
# 삭제 완료
#   지원번호  국어   영어   수학  과학  사회
# 0   1번  90   85  100  95  85
# 1   2번  40   35   50  55  25
# 2   3번  80   75   70  80  75
# 3   4번  40   60   70  75  80
# 4   5번  15   20   10  35  10
# 5   6번  80  100   95  85  80
# 6   7번  55   65   45  40  35
