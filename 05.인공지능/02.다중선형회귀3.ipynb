# %%
import matplotlib.pyplot as plt
plt.rc('font', family='Malgun Gothic')
plt.rc('axes', unicode_minus=False)

import pandas as pd
dataset = pd.read_csv('data/MultipleLinearRegressionData.csv')
dataset.head()
# Out:
#    hour  absent    place  score
# 0   0.5       3     Home     10
# 1   1.2       4  Library      8
# 2   1.8       2     Cafe     14
# 3   2.4       0     Cafe     26
# 4   2.6       2     Home     22

# %%
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values
X, y
# Out:
# (array([[0.5, 3, 'Home'],
#         [1.2, 4, 'Library'],
#         [1.8, 2, 'Cafe'],
#         [2.4, 0, 'Cafe'],
#         [2.6, 2, 'Home'],
#         [3.2, 0, 'Home'],
#         [3.9, 0, 'Library'],
#         [4.4, 0, 'Library'],
#         [4.5, 5, 'Home'],
#         [5.0, 1, 'Cafe'],
#         [5.3, 2, 'Cafe'],
#         [5.8, 0, 'Cafe'],
#         [6.0, 3, 'Library'],
#         [6.1, 1, 'Cafe'],
#         [6.2, 1, 'Library'],
#         [6.9, 4, 'Home'],
#         [7.2, 2, 'Cafe'],
#         [8.4, 1, 'Home'],
#         [8.6, 1, 'Library'],
#         [10.0, 0, 'Library']], dtype=object),
#  array([ 10,   8,  14,  26,  22,  30,  42,  48,  38,  58,  60,  72,  62,
#          68,  72,  58,  76,  86,  90, 100]))

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
ct = ColumnTransformer(
    transformers=[('encoder', OneHotEncoder(drop='first'), [2])],
    remainder='passthrough'
)
X_trans = ct.fit_transform(X)
X_trans[:5], X[:5]
# Out:
# (array([[1.0, 0.0, 0.5, 3],
#         [0.0, 1.0, 1.2, 4],
#         [0.0, 0.0, 1.8, 2],
#         [0.0, 0.0, 2.4, 0],
#         [1.0, 0.0, 2.6, 2]], dtype=object),
#  array([[0.5, 3, 'Home'],
#         [1.2, 4, 'Library'],
#         [1.8, 2, 'Cafe'],
#         [2.4, 0, 'Cafe'],
#         [2.6, 2, 'Home']], dtype=object))

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_trans, y, 
                                                    test_size=0.2, random_state=0)
X_train.shape , X_trans.shape , X_test.shape
# Out:
# ((16, 4), (20, 4), (4, 4))

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = reg.predict(X_train)
y_pred, y_train
# Out:
# (array([57.22323961, 85.29111777, 44.89686182, 67.18859687, 23.30478412,
#         20.80855613, 32.83130336, 67.18450992, 55.74398206, 50.09895946,
#         76.99121064, 65.70933932, 30.33507537, -0.186027  , 64.75882175,
#         61.8196688 ]),
#  array([60, 86, 42, 68, 22, 14, 30, 72, 58, 48, 76, 72, 26, 10, 58, 62]))

# %%
y_pred = reg.predict(X_test)
y_pred, y_test
# Out:
# (array([ 92.15457859,  10.23753043, 108.36245302,  38.14675204]),
#  array([ 90,   8, 100,  38]))

# %%
reg.coef_ , reg.intercept_
# Out:
# (array([-5.82712824, -1.04450647, 10.40419528, -1.64200104]),
#  np.float64(5.3650067065447615))

# %%
X_train[0]
# Out:
# array([0.0, 0.0, 5.3, 2], dtype=object)

# %%
x = ['집', '도서관', '카페', '공부시간', '결석횟수']
y = [reg.coef_[0], reg.coef_[1], 0 , reg.coef_[2], reg.coef_[3]]
plt.figure(figsize=(10, 3))
plt.plot(x, y, color='gray', marker='o')
plt.grid(True, ls='--')
for idx in range(len(x)):
    plt.text(idx, y[idx]+1, f'{y[idx]:.2f}', size=8)
plt.ylim(-7, 15)
plt.yticks([y for y in range(-7, 15, 3)])
plt.show()

# %%
def model_multi():
    import pandas as pd 
    dataset = pd.read_csv('data/MultipleLinearRegressionData.csv')
    X = dataset.iloc[:, :-1].values
    y = dataset.iloc[:, -1].values
    from sklearn.compose import ColumnTransformer
    from sklearn.preprocessing import OneHotEncoder
    ct = ColumnTransformer(
    transformers=[('encoder', OneHotEncoder(drop='first'), [2])],
    remainder='passthrough'
    )
    X_trans = ct.fit_transform(X)
    
    from sklearn.model_selection import train_test_split
    X_train, X_test, y_train, y_test = train_test_split(X_trans, y, 
                                                    test_size=0.2, random_state=0)
    
    from sklearn.linear_model import LinearRegression
    reg = LinearRegression()
    reg.fit(X_train, y_train)
    return reg

# %%
model = model_multi()

# %%
#집에서 9시간 공부, 결석 1번, 점수는? / 카페에서 4시간 공부, 결석 3번, 점수는?
pred=model.predict([[1,0,9,1], [0,0,4,3]])
print(pred[0], pred[1])
# Out:
# 91.53363493726826 42.05578471067582

# %%
dict = {'집':[1, 0], '도서관':[0.1], '카페':[0,0]}
place = '집'
p1 = dict.get(place)[0]
p2 = dict.get(place)[1]
hour = 9
absent = 1

model.predict([[p1, p2, hour, absent]])
# Out:
# array([91.53363494])

# %%
def predict(place, hour, absent):
    dict = {'집':[1, 0], '도서관':[0.1], '카페':[0,0]}
    p1 = dict.get(place)[0]
    p2 = dict.get(place)[1]
    model.predict([[p1, p2, hour, absent]]) 
    print(f'장소:{place}, 공부시간:{hour}, 결석횟수:{absent}, 예상점수:{pred[0]:.2f}점')

# %%
predict('집', 9, 1)
# Out:
# 장소:집, 공부시간:9, 결석횟수:1, 예상점수:91.53점

# %%
model.score(X_train, y_train), model.score(X_test, y_test)
# Out:
# (0.9623352565265527, 0.9859956178877446)

# %%
X_train
# Out:
# array([[0.0, 0.0, 5.3, 2],
#        [1.0, 0.0, 8.4, 1],
#        [0.0, 1.0, 3.9, 0],
#        [0.0, 0.0, 6.1, 1],
#        [1.0, 0.0, 2.6, 2],
#        [0.0, 0.0, 1.8, 2],
#        [1.0, 0.0, 3.2, 0],
#        [0.0, 1.0, 6.2, 1],
#        [0.0, 0.0, 5.0, 1],
#        [0.0, 1.0, 4.4, 0],
#        [0.0, 0.0, 7.2, 2],
#        [0.0, 0.0, 5.8, 0],
#        [0.0, 0.0, 2.4, 0],
#        [1.0, 0.0, 0.5, 3],
#        [1.0, 0.0, 6.9, 4],
#        [0.0, 1.0, 6.0, 3]], dtype=object)

# %%
xticks = [f'{x}' for x in X_train]
xticks
# Out:
# ['[0.0 0.0 5.3 2]',
#  '[1.0 0.0 8.4 1]',
#  '[0.0 1.0 3.9 0]',
#  '[0.0 0.0 6.1 1]',
#  '[1.0 0.0 2.6 2]',
#  '[0.0 0.0 1.8 2]',
#  '[1.0 0.0 3.2 0]',
#  '[0.0 1.0 6.2 1]',
#  '[0.0 0.0 5.0 1]',
#  '[0.0 1.0 4.4 0]',
#  '[0.0 0.0 7.2 2]',
#  '[0.0 0.0 5.8 0]',
#  '[0.0 0.0 2.4 0]',
#  '[1.0 0.0 0.5 3]',
#  '[1.0 0.0 6.9 4]',
#  '[0.0 1.0 6.0 3]']

# %%
def place(x0, x1):
    places = {'10':'집', '01':'도서관', '00':'카페' }
    x0 = int(x0)
    x1 = int(x1)
    x = f'{x0}{x1}'
    return places[x]

place(0.0, 0.1)
# Out:
# '카페'

# %%
xticks = [f'시간:{x[2]}, 결석:{x[3]}' for x in X_train]
xticks
# Out:
# ['시간:5.3, 결석:2',
#  '시간:8.4, 결석:1',
#  '시간:3.9, 결석:0',
#  '시간:6.1, 결석:1',
#  '시간:2.6, 결석:2',
#  '시간:1.8, 결석:2',
#  '시간:3.2, 결석:0',
#  '시간:6.2, 결석:1',
#  '시간:5.0, 결석:1',
#  '시간:4.4, 결석:0',
#  '시간:7.2, 결석:2',
#  '시간:5.8, 결석:0',
#  '시간:2.4, 결석:0',
#  '시간:0.5, 결석:3',
#  '시간:6.9, 결석:4',
#  '시간:6.0, 결석:3']

# %%
xticks = [f'{place(x[0],x[1])}(시간:{x[2]}, 결석:{x[3]})' for x in X_train]
xticks
# Out:
# ['카페(시간:5.3, 결석:2)',
#  '집(시간:8.4, 결석:1)',
#  '도서관(시간:3.9, 결석:0)',
#  '카페(시간:6.1, 결석:1)',
#  '집(시간:2.6, 결석:2)',
#  '카페(시간:1.8, 결석:2)',
#  '집(시간:3.2, 결석:0)',
#  '도서관(시간:6.2, 결석:1)',
#  '카페(시간:5.0, 결석:1)',
#  '도서관(시간:4.4, 결석:0)',
#  '카페(시간:7.2, 결석:2)',
#  '카페(시간:5.8, 결석:0)',
#  '카페(시간:2.4, 결석:0)',
#  '집(시간:0.5, 결석:3)',
#  '집(시간:6.9, 결석:4)',
#  '도서관(시간:6.0, 결석:3)']

# %%
x = [idx for idx, x in enumerate(X_train)]
plt.figure(figsize=(10,3))
plt.plot(x, y_train, color='black', marker='o', label= '실제점수')
plt.plot(x, reg.predict(X_train), color='gray' ,marker='o', label= '예측점수')
plt.legend()
plt.xticks(x, xticks, size=8, rotation=60)
plt.show()

# %%
df = pd.read_csv('data/다중선형회귀.csv')
df
# Out:
#   name  hour  absent    place
# 0  홍길동  10.0       3     Home
# 1  심청이   8.5       4  Library
# 2  강감찬   5.5       2     Cafe
# 3  성춘향   2.4       0     Cafe
# 4  이몽룡   2.6       2     Home
# 5  나철산   3.2       0     Home
# 6  최광명   9.5       0  Library
# 7  박금천   6.9       0  Library
# 8  서가산   4.5       5     Home
# 9  대한민   5.0       1     Cafe

# %%
pred_y = model.predict(X_train)
pred_y
# Out:
# array([57.22323961, 85.29111777, 44.89686182, 67.18859687, 23.30478412,
#        20.80855613, 32.83130336, 67.18450992, 55.74398206, 50.09895946,
#        76.99121064, 65.70933932, 30.33507537, -0.186027  , 64.75882175,
#        61.8196688 ])

# %%
X_df = df.iloc[:, 1:4].values
X_df
# Out:
# array([[10.0, 3, 'Home'],
#        [8.5, 4, 'Library'],
#        [5.5, 2, 'Cafe'],
#        [2.4, 0, 'Cafe'],
#        [2.6, 2, 'Home'],
#        [3.2, 0, 'Home'],
#        [9.5, 0, 'Library'],
#        [6.9, 0, 'Library'],
#        [4.5, 5, 'Home'],
#        [5.0, 1, 'Cafe']], dtype=object)

# %%
ct = ColumnTransformer(
    transformers=[('encoder', OneHotEncoder(drop='first'), [2])],
    remainder='passthrough'
    )
X_trans = ct.fit_transform(X_df)

# %%
X_trans[:5]
# Out:
# array([[1.0, 0.0, 10.0, 3],
#        [0.0, 1.0, 8.5, 4],
#        [0.0, 0.0, 5.5, 2],
#        [0.0, 0.0, 2.4, 0],
#        [1.0, 0.0, 2.6, 2]], dtype=object)

# %%
y_pred = reg.predict(X_trans)
y_pred
# Out:
# array([ 98.65382814,  86.18815596,  59.30407866,  30.33507537,
#         23.30478412,  32.83130336, 103.16035538,  76.10944765,
#         38.14675204,  55.74398206])

# %%
df_y = pd.DataFrame(y_pred)
df_y.head()
# Out:
#            0
# 0  98.653828
# 1  86.188156
# 2  59.304079
# 3  30.335075
# 4  23.304784

# %%
join = df.join(df_y)
join
# Out:
#   name  hour  absent    place           0
# 0  홍길동  10.0       3     Home   98.653828
# 1  심청이   8.5       4  Library   86.188156
# 2  강감찬   5.5       2     Cafe   59.304079
# 3  성춘향   2.4       0     Cafe   30.335075
# 4  이몽룡   2.6       2     Home   23.304784
# 5  나철산   3.2       0     Home   32.831303
# 6  최광명   9.5       0  Library  103.160355
# 7  박금천   6.9       0  Library   76.109448
# 8  서가산   4.5       5     Home   38.146752
# 9  대한민   5.0       1     Cafe   55.743982

# %%
join.rename(columns={0:'예측점수'})
# Out:
#   name  hour  absent    place        예측점수
# 0  홍길동  10.0       3     Home   98.653828
# 1  심청이   8.5       4  Library   86.188156
# 2  강감찬   5.5       2     Cafe   59.304079
# 3  성춘향   2.4       0     Cafe   30.335075
# 4  이몽룡   2.6       2     Home   23.304784
# 5  나철산   3.2       0     Home   32.831303
# 6  최광명   9.5       0  Library  103.160355
# 7  박금천   6.9       0  Library   76.109448
# 8  서가산   4.5       5     Home   38.146752
# 9  대한민   5.0       1     Cafe   55.743982
