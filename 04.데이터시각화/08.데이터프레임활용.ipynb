# %%
import pandas as pd
df = pd.read_csv('data/score.csv', index_col='지원번호')

import matplotlib.pyplot as plt

plt.rc('font', family = 'Malgun Gothic')
plt.rc('font', size = 10)
plt.rc('axes', unicode_minus= False)

# %%
df
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  북산고  197   90   85  100  95  85      Python
# 2번    정대만  북산고  184   40   35   50  55  25        Java
# 3번    송태섭  북산고  168   80   75   70  80  75  Javascript
# 4번    서태웅  북산고  187   40   60   70  75  80        Java
# 5번    강백호  북산고  188   15   20   10  35  10        Java
# 6번    변덕규  능남고  202   80  100   95  85  80          C#
# 7번    황태산  능남고  188   55   65   45  40  35      Python
# 8번    윤대협  능남고  190  100   85   90  95  95          C#
# 9번    홍길동  산북고  190  100   85   90  95  95          C#
# 10번   강감찬  남능고  190  100   85   90  95  95        java
# 11번   이순신  산북고  190  100   85   90  95  95      Python
# 12번   성춘향  산북고  190  100   85   90  95  95      Python
# 13번   이몽룡  남능고  190  100   85   90  95  95        Java

# %%
df.loc['3번','학교'] = '철산고'
df
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  북산고  197   90   85  100  95  85      Python
# 2번    정대만  북산고  184   40   35   50  55  25        Java
# 3번    송태섭  철산고  168   80   75   70  80  75  Javascript
# 4번    서태웅  북산고  187   40   60   70  75  80        Java
# 5번    강백호  북산고  188   15   20   10  35  10        Java
# 6번    변덕규  능남고  202   80  100   95  85  80          C#
# 7번    황태산  능남고  188   55   65   45  40  35      Python
# 8번    윤대협  능남고  190  100   85   90  95  95          C#
# 9번    홍길동  산북고  190  100   85   90  95  95          C#
# 10번   강감찬  남능고  190  100   85   90  95  95        java
# 11번   이순신  산북고  190  100   85   90  95  95      Python
# 12번   성춘향  산북고  190  100   85   90  95  95      Python
# 13번   이몽룡  남능고  190  100   85   90  95  95        Java

# %%
df.loc['7번','학교'] = '금천고'
df
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  북산고  197   90   85  100  95  85      Python
# 2번    정대만  북산고  184   40   35   50  55  25        Java
# 3번    송태섭  철산고  168   80   75   70  80  75  Javascript
# 4번    서태웅  북산고  187   40   60   70  75  80        Java
# 5번    강백호  북산고  188   15   20   10  35  10        Java
# 6번    변덕규  능남고  202   80  100   95  85  80          C#
# 7번    황태산  금천고  188   55   65   45  40  35      Python
# 8번    윤대협  능남고  190  100   85   90  95  95          C#
# 9번    홍길동  산북고  190  100   85   90  95  95          C#
# 10번   강감찬  남능고  190  100   85   90  95  95        java
# 11번   이순신  산북고  190  100   85   90  95  95      Python
# 12번   성춘향  산북고  190  100   85   90  95  95      Python
# 13번   이몽룡  남능고  190  100   85   90  95  95        Java

# %%
group = df.groupby('학교')['키'].mean()
group
# Out:
# 학교
# 금천고    188.0
# 남능고    190.0
# 능남고    196.0
# 북산고    189.0
# 산북고    190.0
# 철산고    168.0
# Name: 키, dtype: float64

# %%
school = group.index
school
# Out:
# Index(['금천고', '남능고', '능남고', '북산고', '산북고', '철산고'], dtype='object', name='학교')

# %%
height = group.values
height
# Out:
# array([188., 190., 196., 189., 190., 168.])

# %%
plt.bar(school, height, color ='black')
for idx, h in enumerate(height):
    plt.text(idx, h+1, f'{h:.2f}cm', ha='center')
plt.xticks(school, [s+'등학교' for s in school], rotation = 45)
plt.show()

# %%
#학교별 학생수 그래프 출력
group = df.groupby('학교').size()
group
# Out:
# 학교
# 금천고    1
# 남능고    2
# 능남고    2
# 북산고    4
# 산북고    3
# 철산고    1
# dtype: int64

# %%
plt.figure(figsize=(5,3))
plt.bar(school, group, color ='black')
for idx, g in enumerate(group):
    plt.text(idx, g+0.1, f'{g}명', ha='center')
plt.xticks(school, [s+'등학교' for s in school], rotation = 45)
plt.ylim(0,5)
plt.show()

# %%
df
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  북산고  197   90   85  100  95  85      Python
# 2번    정대만  북산고  184   40   35   50  55  25        Java
# 3번    송태섭  철산고  168   80   75   70  80  75  Javascript
# 4번    서태웅  북산고  187   40   60   70  75  80        Java
# 5번    강백호  북산고  188   15   20   10  35  10        Java
# 6번    변덕규  능남고  202   80  100   95  85  80          C#
# 7번    황태산  금천고  188   55   65   45  40  35      Python
# 8번    윤대협  능남고  190  100   85   90  95  95          C#
# 9번    홍길동  산북고  190  100   85   90  95  95          C#
# 10번   강감찬  남능고  190  100   85   90  95  95        java
# 11번   이순신  산북고  190  100   85   90  95  95      Python
# 12번   성춘향  산북고  190  100   85   90  95  95      Python
# 13번   이몽룡  남능고  190  100   85   90  95  95        Java

# %%
df['SW특기'] = df['SW특기'].str.capitalize()
df.fillna({'SW특기':'없음'}, inplace = True)
df
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  북산고  197   90   85  100  95  85      Python
# 2번    정대만  북산고  184   40   35   50  55  25        Java
# 3번    송태섭  철산고  168   80   75   70  80  75  Javascript
# 4번    서태웅  북산고  187   40   60   70  75  80        Java
# 5번    강백호  북산고  188   15   20   10  35  10        Java
# 6번    변덕규  능남고  202   80  100   95  85  80          C#
# 7번    황태산  금천고  188   55   65   45  40  35      Python
# 8번    윤대협  능남고  190  100   85   90  95  95          C#
# 9번    홍길동  산북고  190  100   85   90  95  95          C#
# 10번   강감찬  남능고  190  100   85   90  95  95        Java
# 11번   이순신  산북고  190  100   85   90  95  95      Python
# 12번   성춘향  산북고  190  100   85   90  95  95      Python
# 13번   이몽룡  남능고  190  100   85   90  95  95        Java

# %%
group = df.groupby('SW특기').size()
group
# Out:
# SW특기
# C#            3
# Java          5
# Javascript    1
# Python        4
# dtype: int64

# %%
sw = group.index
sw
# Out:
# Index(['C#', 'Java', 'Javascript', 'Python'], dtype='object', name='SW특기')

# %%
count = group.values
count
# Out:
# array([3, 5, 1, 4])

# %%
plt.figure(figsize=(6,3))
plt.title('SW특기자', size = 10)
plt.bar(sw, count, color ='black')
plt.show()

# %%
#학교별 평균 점수
df['평균'] = df.apply(lambda row: row['국어':'사회'].mean(), axis = 1)
df
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기    평균
# 지원번호
# 1번    채치수  북산고  197   90   85  100  95  85      Python  91.0
# 2번    정대만  북산고  184   40   35   50  55  25        Java  41.0
# 3번    송태섭  철산고  168   80   75   70  80  75  Javascript  76.0
# 4번    서태웅  북산고  187   40   60   70  75  80        Java  65.0
# 5번    강백호  북산고  188   15   20   10  35  10        Java  18.0
# 6번    변덕규  능남고  202   80  100   95  85  80          C#  88.0
# 7번    황태산  금천고  188   55   65   45  40  35      Python  48.0
# 8번    윤대협  능남고  190  100   85   90  95  95          C#  93.0
# 9번    홍길동  산북고  190  100   85   90  95  95          C#  93.0
# 10번   강감찬  남능고  190  100   85   90  95  95        Java  93.0
# 11번   이순신  산북고  190  100   85   90  95  95      Python  93.0
# 12번   성춘향  산북고  190  100   85   90  95  95      Python  93.0
# 13번   이몽룡  남능고  190  100   85   90  95  95        Java  93.0

# %%
group = df.groupby('학교')['평균'].mean()
group
# Out:
# 학교
# 금천고    48.00
# 남능고    93.00
# 능남고    90.50
# 북산고    53.75
# 산북고    93.00
# 철산고    76.00
# Name: 평균, dtype: float64

# %%
plt.figure(figsize=(6,3))
plt.title('학교별 평균', size = 10)
plt.bar(school, group, color ='black')
for idx, g in enumerate(group):
    plt.text(idx, g+0.3, f'{g:.1f}점',  ha='center')
plt.xticks(school, [s+'등학교' for s in school], rotation = 45)
plt.yticks([y for y in range(0, 101, 10)])
plt.ylim(0,100)
plt.show()

# %%
plt.figure(figsize=(5,3))
plt.title('학교별 평균', size = 10)
plt.bar(school, group, color ='black')
for idx, g in enumerate(group):
    plt.text(idx, g+0.3, f'{g:.2f}',  ha='center')
yticks = [y for y in range(0,101,10)]
plt.yticks(yticks, [f'{y}점' for y in yticks])
plt.xticks(school, [s+'등학교' for s in school], rotation = 45)
plt.ylim(0,100)
plt.show()

# %%
import pandas as pd
df = pd.read_csv('data/score.csv', index_col='지원번호')

import matplotlib.pyplot as plt

plt.rc('font', family = 'Malgun Gothic')
plt.rc('font', size = 10)
plt.rc('axes', unicode_minus= False)

# %%
name = df['이름']
height = df['키']
plt.figure(figsize=(10,3))
plt.ylim(150,210)
plt.bar(name, height, color='black')
plt.xticks(name, rotation=45, size=10)
for idx, h in enumerate(height):
    plt.text(idx, h+1, h, ha='center', size=8)

# %%
df['평균'] = df.apply(lambda row:row['국어':'사회'].mean(), axis=1)
name = df['이름']
avg = df['평균']
plt.figure(figsize=(10,3))
plt.ylim(0,100)
plt.bar(name, avg, color='black')
plt.xticks(name, rotation=45, size=10)
for idx, h in enumerate(avg):
    plt.text(idx, h+1, f'{h:.2f}', ha='center', size=8)

# %%
df['평균'] = df.apply(lambda row:row['국어':'사회'].mean(), axis=1)
group = df.groupby('학교')['평균'].mean()
labels = group.index
values = group.values
plt.figure(figsize=(10,5))
plt.ylim(0,100)
plt.bar(labels, values, color='black',width = 0.5)
plt.xticks(labels, rotation=45, size=8)
for idx, value in enumerate(values):
    plt.text(idx, value+1, f'{value:.2f}', ha='center', size=8)

# %%
group = df.groupby('학교')['키'].mean()
group
# Out:
# 학교
# 남능고    190.000000
# 능남고    193.333333
# 북산고    184.800000
# 산북고    190.000000
# Name: 키, dtype: float64

# %%
df['SW특기'] = df['SW특기'].str.capitalize()
group = df.groupby('SW특기').size()
group
# Out:
# SW특기
# C#            3
# Java          5
# Javascript    1
# Python        4
# dtype: int64

# %%
df['SW특기'] = df['SW특기'].str.capitalize()
group = df.groupby('SW특기').size()
labels = group.index
values = group.values
plt.figure(figsize=(10, 5))
plt.ylim(0, 6)
plt.bar(labels, values, color='black', width=0.5)
plt.xticks(labels, rotation=45, size=10, color='g')
for idx, value in enumerate(values):
    plt.text(idx, value+0.03, f'{value}명', ha='center', color='g', size=10)

# %%
#학생별 평균점수
enroll = pd.read_csv('data/수강.csv')
group = enroll.groupby('학생번호')['점수'].mean().to_frame()
group
# Out:
#                  점수
# 학생번호
# 92414029  81.250000
# 92414033  82.500000
# 92454018  90.000000
# 92514009  77.500000
# 92514023  70.000000
# 95414058  83.333333
# 95454003  81.000000
# 96414404  75.000000

# %%
stu = pd.read_csv('data/학생.csv')
merge = stu.merge(group, how = 'left', on= '학생번호')
merge
# Out:
#        학생번호 학생이름 학생학과  학년      생년월일  지도교수         점수
# 0  92414029  서연우   전산   3  73/10/06   228  81.250000
# 1  92414033  김창덕   전산   4  73/10/26   221  82.500000
# 2  92514009  이지행   전자   4  73/11/16   311  77.500000
# 3  92514023  김형명   전자   4  73/08/29   311  70.000000
# 4  92454018  이원구   건축   3  74/09/30   509  90.000000
# 5  95454003  이재영   건축   4  76/02/06   509  81.000000
# 6  95414058  박혜경   전산   4  76/03/12   221  83.333333
# 7  96414404  김수정   전산   3  77/12/22   228  75.000000
