# %%
import matplotlib.pyplot as plt

plt.rc('font', family = 'Malgun Gothic')
plt.rc('font', size = 10)
plt.rc('axes', unicode_minus= False)

# %%
import pandas as pd
df = pd.read_csv('data/score.csv')

# %%
df['평균'] = df.apply(lambda row:row['국어':'사회'].mean(), axis=1)
df
# Out:
#   지원번호   이름   학교    키   국어   영어   수학  과학  사회        SW특기    평균
# 0   1번  채치수  북산고  197   90   85  100  95  85      Python  91.0
# 1   2번  정대만  북산고  184   40   35   50  55  25        Java  41.0
# 2   3번  송태섭  북산고  168   80   75   70  80  75  Javascript  76.0
# 3   4번  서태웅  북산고  187   40   60   70  75  80        Java  65.0
# 4   5번  강백호  북산고  188   15   20   10  35  10        Java  18.0
# 5   6번  변덕규  능남고  202   80  100   95  85  80          C#  88.0
# 6   7번  황태산  능남고  188   55   65   45  40  35      Python  48.0
# 7   8번  윤대협  능남고  190  100   85   90  95  95          C#  93.0

# %%
fig, ax = plt.subplots(figsize=(10,5))
ax.bar(df['이름'], df['평균'], color = 'black')
ax.set_ylabel('평균점수')
ax.set_ylim(0, 150)
yticks = [y for y in range(0,101,20)]
ax.set_yticks(yticks)


ax2 = ax.twinx()
ax2.set_ylabel('키')
ax2.set_ylim(0, 250)
ax2.plot(df['이름'], df['키'], color='red', marker='o')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,5))
ax.bar(df['이름'], df['평균'], color = 'black')
ax.set_ylabel('평균점수')
ax.set_ylim(0, 150)
yticks = [y for y in range(0,101,20)]
ax.set_yticks(yticks, [f'{y}점' for y in range(0,101,20)])


ax2 = ax.twinx()
ax2.set_ylabel('키')
ax2.set_ylim(0, 250)
ax2.plot(df['이름'], df['키'], color='red', marker='o')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,5))
ax.bar(df['이름'], df['평균'], color = 'black')
ax.set_xticks(df['이름'], df['이름']+'님')
ax.set_ylabel('평균점수')
ax.set_ylim(0, 150)
yticks = [y for y in range(0,101,20)]
ax.set_yticks(yticks, [f'{y}점' for y in range(0,101,20)])
for idx, y in enumerate(df['평균']):
    ax.text(idx, y-5, f'{y:.0f}점', ha='center' ,color="yellow")


ax2 = ax.twinx()
ax2.set_ylabel('키')
ax2.set_ylim(0, 250)
ax2.plot(df['이름'], df['키'], color='red', marker='o')
yticks = [y for y in range(0,251,50)]
ax2.set_yticks(yticks, [f'{y}cm' for y in range(0,251,50)])
for idx, y in enumerate(df['키']):
    ax2.text(idx, y+2, f'{y}cm', ha='center')

plt.savefig('data/평균점수와 키.png')
plt.show()
